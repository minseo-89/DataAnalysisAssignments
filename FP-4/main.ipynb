# %%
import parse_data as pd_data   
import descriptive as desc

# %%
df = pd_data.get_data('MentalHealthSurvey.csv')
# Out:
# Successfully loaded 'MentalHealthSurvey.csv'

# %%
if df is not None:
    desc.display_central_tendency_table(df, num=1)
    desc.display_dispersion_table(df, num=2)
    desc.plot_descriptive(df)
# Out:
# <p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#           age  depression  academic_pressure  financial_concerns
# Mean    19.94        3.22               3.78                3.39
# Median  20.00        3.00               4.00                3.00
# Mode    20.00        3.00               4.00                5.00
# <p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#           age  depression  academic_pressure  financial_concerns
# St.Dev   1.62        1.37               1.13                 1.4
# Min     17.00        1.00               1.00                 1.0
# Max     26.00        5.00               5.00                 5.0
# Range    9.00        4.00               4.00                 4.0
# 25%     19.00        2.00               3.00                 2.5
# 75%     21.00        4.00               5.00                 5.0
# IQR      2.00        2.00               2.00                 2.5
# ...
